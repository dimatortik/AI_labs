# %%
import os
import time
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
    BatchNormalization, Input, GlobalAveragePooling2D,
    SeparableConv2D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, precision_recall_fscore_support
)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

extract_path = "/kaggle/input/animals10/raw-img"

external_test_folder = "/kaggle/input/external-test-image"

img_size = (227, 227)
BATCH_SIZE = 32
EPOCHS = 15

TRAIN_VARIANT = True

datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    extract_path,
    target_size=img_size,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=SEED
)

val_generator = datagen.flow_from_directory(
    extract_path,
    target_size=img_size,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=SEED
)

class_names = list(train_generator.class_indices.keys())
NUM_CLASSES = len(class_names)
print("Класи:", class_names)

def build_alexnet(input_shape=(227, 227, 3), num_classes=10):
    model = Sequential([
        Input(shape=input_shape),

        Conv2D(96, (11, 11), strides=4, activation='relu'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        Conv2D(256, (5, 5), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        Conv2D(384, (3, 3), activation='relu', padding='same'),
        Conv2D(384, (3, 3), activation='relu', padding='same'),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

def build_alexnet_variant(input_shape=(227, 227, 3), num_classes=10):
    model = Sequential([
        Input(shape=input_shape),

        Conv2D(96, (11, 11), strides=4, activation='relu'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        SeparableConv2D(256, (5, 5), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        SeparableConv2D(384, (3, 3), activation='relu', padding='same'),
        SeparableConv2D(384, (3, 3), activation='relu', padding='same'),
        SeparableConv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

def compile_and_train(model, train_gen, val_gen, epochs=EPOCHS, learning_rate=1e-4):
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    callbacks = [
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            verbose=1
        ),
        EarlyStopping(
            monitor='val_loss',
            patience=6,
            restore_best_weights=True,
            verbose=1
        )
    ]

    start = time.time()
    history = model.fit(
        train_gen,
        epochs=epochs,
        validation_data=val_gen,
        callbacks=callbacks,
        verbose=2
    )
    end = time.time()
    total_time = end - start
    time_per_epoch = total_time / len(history.history['loss'])
    return history, total_time, time_per_epoch


def evaluate_model(model, val_gen, class_names):
    steps = val_gen.samples // val_gen.batch_size + int(val_gen.samples % val_gen.batch_size != 0)
    preds = model.predict(val_gen, steps=steps, verbose=0)
    y_pred = np.argmax(preds, axis=1)
    y_true = val_gen.classes

    acc = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred,
        average='weighted',
        zero_division=0
    )
    report = classification_report(
        y_true, y_pred,
        target_names=class_names,
        zero_division=0
    )
    cm = confusion_matrix(y_true, y_pred)

    return {
        "accuracy": acc,
        "precision_weighted": precision,
        "recall_weighted": recall,
        "f1_weighted": f1,
        "report": report,
        "confusion_matrix": cm,
        "y_true": y_true,
        "y_pred": y_pred
    }


def plot_history(history, title_suffix=""):
    acc = history.history.get('accuracy', [])
    val_acc = history.history.get('val_accuracy', [])
    losses = history.history.get('loss', [])
    val_losses = history.history.get('val_loss', [])
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='train acc')
    plt.plot(epochs_range, val_acc, label='val acc')
    plt.legend()
    plt.title('Accuracy ' + title_suffix)

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, losses, label='train loss')
    plt.plot(epochs_range, val_losses, label='val loss')
    plt.legend()
    plt.title('Loss ' + title_suffix)

    plt.show()


def plot_confusion_matrix(cm, class_names, title="Confusion matrix"):
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        xticklabels=class_names,
        yticklabels=class_names,
        cmap='Blues'
    )
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(title)
    plt.show()


def predict_external_images(folder_path, model, img_size, class_names):
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} not found. Put external images there and run again.")
        return []

    results = []
    for fname in os.listdir(folder_path):
        fp = os.path.join(folder_path, fname)
        try:
            img = image.load_img(fp, target_size=img_size)
            arr = image.img_to_array(img) / 255.0
            arr = np.expand_dims(arr, axis=0)
            pred = model.predict(arr)
            cls = class_names[np.argmax(pred)]
            results.append((fname, cls))

            plt.imshow(img)
            plt.axis('off')
            plt.title(f"{fname} -> {cls}")
            plt.show()
        except Exception as ex:
            print(f"Failed to process {fp}: {ex}")
    return results

def save_random_predictions_to_csv(
    model,
    extract_path,
    img_size,
    class_names,
    num_images=1024,
    out_csv="/kaggle/working/classification_results.csv"
):
    all_images = []
    for class_name in os.listdir(extract_path):
        class_dir = os.path.join(extract_path, class_name)
        if os.path.isdir(class_dir):
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                all_images.append((img_path, class_name))

    if len(all_images) == 0:
        print("No images found for CSV export.")
        return

    selected_images = random.sample(all_images, min(num_images, len(all_images)))
    results = []
    batch_size = 128

    def load_batch(image_data):
        images, paths, true_classes = [], [], []
        for img_path, true_class in image_data:
            img = image.load_img(img_path, target_size=img_size)
            img_array = image.img_to_array(img) / 255.0
            images.append(img_array)
            paths.append(img_path)
            true_classes.append(true_class)
        return np.array(images), paths, true_classes

    for i in range(0, len(selected_images), batch_size):
        batch_data = selected_images[i:i+batch_size]
        batch_images, batch_paths, batch_true_classes = load_batch(batch_data)
        preds = model.predict(batch_images)
        pred_classes = np.argmax(preds, axis=1)

        for j in range(len(batch_paths)):
            results.append([
                batch_paths[j],
                batch_true_classes[j],
                class_names[pred_classes[j]]
            ])

    df = pd.DataFrame(results, columns=["path", "true_class", "predicted_class"])
    df.to_csv(out_csv, index=False, encoding="utf-8")
    print(f"Saved predictions to {out_csv}")

print("\n=== BUILD & TRAIN ORIGINAL ALEXNET ===")
orig_model = build_alexnet(input_shape=(227, 227, 3), num_classes=NUM_CLASSES)
print(orig_model.summary())

history_orig, total_time_orig, time_per_epoch_orig = compile_and_train(
    orig_model,
    train_generator,
    val_generator,
    epochs=EPOCHS
)

print(f"Total training time (original): {total_time_orig:.1f}s, "
      f"time/epoch ≈ {time_per_epoch_orig:.1f}s")

plot_history(history_orig, title_suffix="(original)")

eval_orig = evaluate_model(orig_model, val_generator, class_names)
print("=== Original AlexNet metrics ===")
print(f"Accuracy: {eval_orig['accuracy']:.4f}")
print(f"Precision (weighted): {eval_orig['precision_weighted']:.4f}")
print(f"Recall (weighted): {eval_orig['recall_weighted']:.4f}")
print(f"F1 (weighted): {eval_orig['f1_weighted']:.4f}")
print("\nClassification report:\n", eval_orig['report'])

plot_confusion_matrix(
    eval_orig['confusion_matrix'],
    class_names,
    title="Confusion Matrix (original)"
)

save_random_predictions_to_csv(
    orig_model,
    extract_path,
    img_size,
    class_names,
    num_images=1024
)

print("\n=== TEST ORIGINAL MODEL ON EXTERNAL IMAGES ===")
external_results = predict_external_images(
    external_test_folder,
    orig_model,
    img_size,
    class_names
)
print("External predictions (original):", external_results)

if TRAIN_VARIANT:
    print("\n=== BUILD & TRAIN VARIANT ALEXNET (optimized) ===")
    var_model = build_alexnet_variant(
        input_shape=(227, 227, 3),
        num_classes=NUM_CLASSES
    )
    print(var_model.summary())

    history_var, total_time_var, time_per_epoch_var = compile_and_train(
        var_model,
        train_generator,
        val_generator,
        epochs=EPOCHS
    )

    print(f"Total training time (variant): {total_time_var:.1f}s, "
          f"time/epoch ≈ {time_per_epoch_var:.1f}s")

    plot_history(history_var, title_suffix="(variant)")

    eval_var = evaluate_model(var_model, val_generator, class_names)
    print("=== Variant AlexNet metrics ===")
    print(f"Accuracy: {eval_var['accuracy']:.4f}")
    print(f"Precision (weighted): {eval_var['precision_weighted']:.4f}")
    print(f"Recall (weighted): {eval_var['recall_weighted']:.4f}")
    print(f"F1 (weighted): {eval_var['f1_weighted']:.4f}")
    print("\nClassification report:\n", eval_var['report'])

    plot_confusion_matrix(
        eval_var['confusion_matrix'],
        class_names,
        title="Confusion Matrix (variant)"
    )

    orig_params = orig_model.count_params()
    var_params = var_model.count_params()
    print("\n=== Comparison ===")
    print(f"Original params: {orig_params:,}")
    print(f"Variant params:  {var_params:,}")
    print(f"Param reduction: {orig_params - var_params:,} "
          f"({100.0 * (orig_params - var_params) / orig_params:.2f}%)")
    print(f"Time/epoch original ≈ {time_per_epoch_orig:.1f}s; "
          f"variant ≈ {time_per_epoch_var:.1f}s")
    print(f"Accuracy original: {eval_orig['accuracy']:.4f}; "
          f"variant: {eval_var['accuracy']:.4f}")
    print(f"F1 original: {eval_orig['f1_weighted']:.4f}; "
          f"variant: {eval_var['f1_weighted']:.4f}")

    print("\n=== TEST VARIANT MODEL ON EXTERNAL IMAGES ===")
    external_results_var = predict_external_images(
        external_test_folder,
        var_model,
        img_size,
        class_names
    )
    print("External predictions (variant):", external_results_var)

print("\n=== Finished ===")
# Out:
# Found 20947 images belonging to 10 classes.
# Found 5232 images belonging to 10 classes.
# Класи: ['cane', 'cavallo', 'elefante', 'farfalla', 'gallina', 'gatto', 'mucca', 'pecora', 'ragno', 'scoiattolo']
#
# === BUILD & TRAIN ORIGINAL ALEXNET ===
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_31 (Conv2D)              │ (None, 55, 55, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 55, 55, 96)     │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 27, 27, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 27, 27, 256)    │       614,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 27, 27, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 13, 13, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 13, 13, 384)    │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 13, 13, 384)    │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 13, 13, 256)    │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 13, 13, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4096)           │    37,752,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 10)             │        40,970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,324,746 (222.49 MB)
#  Trainable params: 58,323,530 (222.49 MB)
#  Non-trainable params: 1,216 (4.75 KB)
# None
# Epoch 1/15
# 655/655 - 65s - 99ms/step - accuracy: 0.3538 - loss: 2.1453 - val_accuracy: 0.3450 - val_loss: 1.7983 - learning_rate: 1.0000e-04
# Epoch 2/15
# 655/655 - 56s - 86ms/step - accuracy: 0.4992 - loss: 1.4867 - val_accuracy: 0.3777 - val_loss: 2.4440 - learning_rate: 1.0000e-04
# Epoch 3/15
# 655/655 - 57s - 86ms/step - accuracy: 0.5719 - loss: 1.2738 - val_accuracy: 0.3523 - val_loss: 2.0247 - learning_rate: 1.0000e-04
# Epoch 4/15
# 655/655 - 57s - 87ms/step - accuracy: 0.6157 - loss: 1.1374 - val_accuracy: 0.5155 - val_loss: 1.4016 - learning_rate: 1.0000e-04
# Epoch 5/15
# 655/655 - 58s - 88ms/step - accuracy: 0.6621 - loss: 1.0049 - val_accuracy: 0.6013 - val_loss: 1.2202 - learning_rate: 1.0000e-04
# Epoch 6/15
# 655/655 - 55s - 84ms/step - accuracy: 0.7027 - loss: 0.8866 - val_accuracy: 0.5904 - val_loss: 1.2911 - learning_rate: 1.0000e-04
# Epoch 7/15
# 655/655 - 55s - 85ms/step - accuracy: 0.7322 - loss: 0.7952 - val_accuracy: 0.5438 - val_loss: 1.3537 - learning_rate: 1.0000e-04
# Epoch 8/15
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 655/655 - 57s - 87ms/step - accuracy: 0.7624 - loss: 0.6965 - val_accuracy: 0.3616 - val_loss: 2.9407 - learning_rate: 1.0000e-04
# Epoch 9/15
# 655/655 - 58s - 88ms/step - accuracy: 0.8449 - loss: 0.4617 - val_accuracy: 0.7538 - val_loss: 0.7333 - learning_rate: 5.0000e-05
# Epoch 10/15
# 655/655 - 56s - 86ms/step - accuracy: 0.8817 - loss: 0.3512 - val_accuracy: 0.7534 - val_loss: 0.7764 - learning_rate: 5.0000e-05
# Epoch 11/15
# 655/655 - 57s - 87ms/step - accuracy: 0.9065 - loss: 0.2740 - val_accuracy: 0.7552 - val_loss: 0.8221 - learning_rate: 5.0000e-05
# Epoch 12/15
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 655/655 - 57s - 88ms/step - accuracy: 0.9232 - loss: 0.2244 - val_accuracy: 0.7592 - val_loss: 0.8072 - learning_rate: 5.0000e-05
# Epoch 13/15
# 655/655 - 59s - 90ms/step - accuracy: 0.9630 - loss: 0.1130 - val_accuracy: 0.7955 - val_loss: 0.7479 - learning_rate: 2.5000e-05
# Epoch 14/15
# 655/655 - 58s - 89ms/step - accuracy: 0.9757 - loss: 0.0764 - val_accuracy: 0.7945 - val_loss: 0.7675 - learning_rate: 2.5000e-05
# Epoch 15/15
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 655/655 - 59s - 90ms/step - accuracy: 0.9795 - loss: 0.0628 - val_accuracy: 0.7976 - val_loss: 0.8132 - learning_rate: 2.5000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Total training time (original): 865.2s, time/epoch ≈ 57.7s
# === Original AlexNet metrics ===
# Accuracy: 0.7538
# Precision (weighted): 0.7679
# Recall (weighted): 0.7538
# F1 (weighted): 0.7556
#
# Classification report:
#                precision    recall  f1-score   support
#
#         cane       0.80      0.72      0.76       972
#      cavallo       0.83      0.70      0.76       524
#     elefante       0.57      0.85      0.68       289
#     farfalla       0.79      0.85      0.82       422
#      gallina       0.92      0.77      0.84       619
#        gatto       0.64      0.58      0.61       333
#        mucca       0.66      0.65      0.65       373
#       pecora       0.71      0.59      0.65       364
#        ragno       0.85      0.91      0.88       964
#   scoiattolo       0.53      0.73      0.61       372
#
#     accuracy                           0.75      5232
#    macro avg       0.73      0.73      0.73      5232
# weighted avg       0.77      0.75      0.76      5232
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved predictions to /kaggle/working/classification_results.csv
#
# === TEST ORIGINAL MODEL ON EXTERNAL IMAGES ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# External predictions (original): [('Horse Meme.jpg', 'pecora')]
#
# === BUILD & TRAIN VARIANT ALEXNET (optimized) ===
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_36 (Conv2D)              │ (None, 55, 55, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 55, 55, 96)     │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 27, 27, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_4              │ (None, 27, 27, 256)    │        27,232 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 27, 27, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 13, 13, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_5              │ (None, 13, 13, 384)    │       100,992 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_6              │ (None, 13, 13, 384)    │       151,296 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_7              │ (None, 13, 13, 256)    │       102,016 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 13, 13, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1024)           │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 692,330 (2.64 MB)
#  Trainable params: 691,114 (2.64 MB)
#  Non-trainable params: 1,216 (4.75 KB)
# None
# Epoch 1/15
# 655/655 - 68s - 103ms/step - accuracy: 0.3471 - loss: 1.8745 - val_accuracy: 0.2815 - val_loss: 2.0131 - learning_rate: 1.0000e-04
# Epoch 2/15
# 655/655 - 55s - 85ms/step - accuracy: 0.4915 - loss: 1.4538 - val_accuracy: 0.4308 - val_loss: 1.5790 - learning_rate: 1.0000e-04
# Epoch 3/15
# 655/655 - 55s - 83ms/step - accuracy: 0.5504 - loss: 1.2984 - val_accuracy: 0.5218 - val_loss: 1.3549 - learning_rate: 1.0000e-04
# Epoch 4/15
# 655/655 - 55s - 84ms/step - accuracy: 0.5921 - loss: 1.1840 - val_accuracy: 0.5805 - val_loss: 1.2281 - learning_rate: 1.0000e-04
# Epoch 5/15
# 655/655 - 55s - 84ms/step - accuracy: 0.6254 - loss: 1.0942 - val_accuracy: 0.5059 - val_loss: 1.5209 - learning_rate: 1.0000e-04
# Epoch 6/15
# 655/655 - 54s - 82ms/step - accuracy: 0.6453 - loss: 1.0297 - val_accuracy: 0.6078 - val_loss: 1.1115 - learning_rate: 1.0000e-04
# Epoch 7/15
# 655/655 - 55s - 84ms/step - accuracy: 0.6706 - loss: 0.9654 - val_accuracy: 0.5923 - val_loss: 1.2638 - learning_rate: 1.0000e-04
# Epoch 8/15
# 655/655 - 54s - 82ms/step - accuracy: 0.6862 - loss: 0.9147 - val_accuracy: 0.6154 - val_loss: 1.1191 - learning_rate: 1.0000e-04
# Epoch 9/15
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 655/655 - 54s - 83ms/step - accuracy: 0.7038 - loss: 0.8703 - val_accuracy: 0.5914 - val_loss: 1.1859 - learning_rate: 1.0000e-04
# Epoch 10/15
# 655/655 - 57s - 86ms/step - accuracy: 0.7339 - loss: 0.7850 - val_accuracy: 0.5963 - val_loss: 1.2884 - learning_rate: 5.0000e-05
# Epoch 11/15
# 655/655 - 56s - 86ms/step - accuracy: 0.7425 - loss: 0.7565 - val_accuracy: 0.6925 - val_loss: 0.9010 - learning_rate: 5.0000e-05
# Epoch 12/15
# 655/655 - 61s - 94ms/step - accuracy: 0.7518 - loss: 0.7293 - val_accuracy: 0.6502 - val_loss: 1.0659 - learning_rate: 5.0000e-05
# Epoch 13/15
# 655/655 - 56s - 85ms/step - accuracy: 0.7587 - loss: 0.7044 - val_accuracy: 0.6713 - val_loss: 0.9632 - learning_rate: 5.0000e-05
# Epoch 14/15
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 655/655 - 57s - 86ms/step - accuracy: 0.7678 - loss: 0.6848 - val_accuracy: 0.6093 - val_loss: 1.2004 - learning_rate: 5.0000e-05
# Epoch 15/15
# 655/655 - 57s - 87ms/step - accuracy: 0.7888 - loss: 0.6304 - val_accuracy: 0.7460 - val_loss: 0.7633 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 15.
# Total training time (variant): 848.9s, time/epoch ≈ 56.6s
# === Variant AlexNet metrics ===
# Accuracy: 0.7460
# Precision (weighted): 0.7528
# Recall (weighted): 0.7460
# F1 (weighted): 0.7436
#
# Classification report:
#                precision    recall  f1-score   support
#
#         cane       0.67      0.83      0.74       972
#      cavallo       0.64      0.79      0.70       524
#     elefante       0.76      0.66      0.71       289
#     farfalla       0.88      0.78      0.83       422
#      gallina       0.88      0.81      0.85       619
#        gatto       0.69      0.48      0.57       333
#        mucca       0.61      0.65      0.63       373
#       pecora       0.73      0.57      0.64       364
#        ragno       0.85      0.88      0.87       964
#   scoiattolo       0.74      0.55      0.63       372
#
#     accuracy                           0.75      5232
#    macro avg       0.74      0.70      0.72      5232
# weighted avg       0.75      0.75      0.74      5232
# === Comparison ===
# Original params: 58,324,746
# Variant params:  692,330
# Param reduction: 57,632,416 (98.81%)
# Time/epoch original ≈ 57.7s; variant ≈ 56.6s
# Accuracy original: 0.7538; variant: 0.7460
# F1 original: 0.7556; variant: 0.7436
#
# === TEST VARIANT MODEL ON EXTERNAL IMAGES ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# External predictions (variant): [('Horse Meme.jpg', 'pecora')]
#
# === Finished ===
